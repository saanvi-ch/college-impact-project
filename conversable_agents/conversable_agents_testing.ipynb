# %%
import os
from autogen import ConversableAgent

# %%
cathy = ConversableAgent(
    "cathy",
    system_message="You are an assistant for mathematicians who is seasoned at providing the steps to solve a problem. You don't actually solve the problem, you only provide the steps for a mathematician to execute.",
    llm_config={"config_list": [{"model": "gpt-4", "temperature": 0.2, "api_key": os.environ.get("OPENAI_API_KEY")}]},
    human_input_mode="NEVER",  # Never ask for human input.
)

joe = ConversableAgent(
    "joe",
    system_message="You are an expert mathematician who is seasoned at solving problems and explaining your solutions.",
    llm_config={"config_list": [{"model": "gpt-4", "temperature": 0.2, "api_key": os.environ.get("OPENAI_API_KEY")}]},
    human_input_mode="NEVER",  # Never ask for human input.
)

# %%
result = joe.initiate_chat(cathy, message = "Cathy, tell me how to solve this problem step-by-step: Let $k, l > 0$ be parameters. The parabola $y = kx^2 - 2kx + l$ intersects the line $y = 4$ at two points $A$ and $B$. These points are distance 6 apart. What is the sum of the squares of the distances from $A$ and $B$ to the origin? Give me one step at a time.", max_turns=4)
# Out:
# joe (to cathy):
#
# Cathy, tell me how to solve this problem step-by-step: Let $k, l > 0$ be parameters. The parabola $y = kx^2 - 2kx + l$ intersects the line $y = 4$ at two points $A$ and $B$. These points are distance 6 apart. What is the sum of the squares of the distances from $A$ and $B$ to the origin? Give me one step at a time.
#
# --------------------------------------------------------------------------------
# cathy (to joe):
#
# Sure, here are the steps to solve the problem:
#
# Step 1:
# First, we need to find the points where the parabola intersects the line y = 4. To do this, we set the equation of the parabola equal to 4 and solve for x.
#
# Step 2:
# The equation becomes $kx^2 - 2kx + l = 4$. Rearrange the equation to get $kx^2 - 2kx + (l - 4) = 0$.
#
# Step 3:
# This is a quadratic equation in the form of $ax^2 + bx + c = 0$, where $a = k$, $b = -2k$, and $c = l - 4$. We can solve for x using the quadratic formula $x = [-b ± sqrt(b^2 - 4ac)] / (2a)$.
#
# Step 4:
# ...
